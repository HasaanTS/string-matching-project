# %%
import requests
from bs4 import BeautifulSoup

# %%
# https://www.opensecrets.org/personal-finances/assets/?cid=N00001024&year=2013
_id = 1024
_year = 2013
site
baseStr = 'https://www.opensecrets.org/personal-finances/assets/?cid=N0000'+str(_id)+'&year='+str(_year)
print baseStr
# Out:
# https://www.opensecrets.org/personal-finances/assets/?cid=N00001024&year=2013

# %%
page = requests.get(baseStr)

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>\n\n<!--[if lte IE 8]><html class="no-js lte-ie9 lte-ie8" lang="en" dir="ltr"><![endif]-->\n<!--[if IE 9]><html class="no-js lte-ie9" lang="en" dir="ltr"><![endif]-->\n<!--[if gt IE 9]><!--><html class="no-js" dir="ltr" lang="en"><!--<![endif]-->\n<head>\n<!-- Google Tag Manager -->\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':\n  new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],\n  j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=\n  'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);\n  })(window,document,'script','dataLayer','GTM-MKPRXNV');</script>\n<!-- End Google Tag Manager -->\n<meta charset="unicode-escape"/>\n<title>Nita M Lowey- Assets - Personal Finances \u2022 OpenSecrets</title>\n<meta content="width=device-width, initial-scale=1.0" name="viewport">\n<link href="https://www.opensecrets.org/personal-finances/assets?cid=N00001024&amp;year=2013" rel="canonical"/>\n<meta content="Nita M Lowey's estimated assets total ranges from $12,280,023.00 to $51,650,000.00 for 2013. Learn more about their investments and net worth." name="description"/>\n<meta content="OpenSecrets" property="og:site_name"/>\n<meta content="Nita M Lowey- Assets - Personal Finances" property="og:title"/>\n<meta content="Nita M Lowey's estimated assets total ranges from $12,280,023.00 to $51,650,000.00 for 2013. Learn more about their investments and net worth." property="og:description"/>\n<meta content="https://www.opensecrets.org/personal-finances/assets?cid=N00001024&amp;year=2013" property="og:url"/>\n<meta content="article" property="og:type"/>\n<meta content="https://www.opensecrets.org/assets/crp-social.png" property="og:image"/>\n<meta content="13220831937" property="fb:pages"/>\n<meta content="summary" name="twitter:card"/>\n<meta content="Nita M Lowey- Assets - Personal Finances" name="twitter:title"/>\n<meta content="Nita M Lowey's estimated assets total ranges from $12,280,023.00 to $51,650,000.00 for 2013. Learn more about their investments and net worth." name="twitter:description"/>\n<meta content="https://d3kmt9nit25k8s.cloudfront.net/img/twitter-card-os-logo.png" name="twitter:image:src"/>\n<meta content="OpenSecrets.org" name="twitter:image:alt"/>\n<meta content="@" name="twitter:creator"/>\n<meta content="https://www.opensecrets.org/" name="twitter:domain"/>\n<script type="application/ld+json">\n{\n  "@context": "http://schema.org",\n  "@type": "Organization",\n  "name": "OpenSecrets",\n  "url": "https://www.opensecrets.org/",\n  "logo": "https://www.opensecrets.org/app-icon.png",\n  "sameAs": [\n    "https://www.facebook.com/OpenSecrets/",\n    "https://twitter.com/OpenSecretsDC"\n  ]\n}\n</script>\n<link href="https://www.opensecrets.org/favicon.ico" rel="shortcut icon" type="image/x-icon"/>\n<meta content="OpenSecrets" name="apple-mobile-web-app-title"/>\n<link href="https://www.opensecrets.org/app-icon.png" rel="apple-touch-icon"/>\n<link href="https://www.opensecrets.org/app-icon.png" rel="icon" sizes="196x196"/>\n<meta content="#FIXME" name="theme-color"/>\n<meta content="authenticity_token" name="csrf-param"/>\n<meta content="PyX2XnVPN7o6yqauqFwRA6NxxnACva5DVoXxEmRWKU1XmOKByfdkJeLFJ/ktsq7ZEBYorYtmXQtfDWcAkIK7dA==" name="csrf-token"/>\n<style>@font-face{font-family:'Open Sans';font-style:normal;font-weight:400;src:local("Open Sans"),local("OpenSans"),url("/assets/open-sans/open-sans-v13-latin-regular-60f9b5203842a4fe2d52f7c96f3c57b755bbf8f347535469739bcc6f95a9c4b5.woff2") format("woff2"),url("/assets/open-sans/open-sans-v13-latin-regular-819747b05df4938922997e60e199603ecb04f4d987331ba5c3f7db30a835c3bd.woff") format("woff")}@font-face{font-family:'Open Sans';font-style:italic;font-weight:400;src:local("Open Sans Italic"),local("OpenSans-Italic"),url("/assets/open-sans/open-sans-v13-latin-italic-31e017acd3e7f361b8415d08e478b431a47929954aa974ff871be87bf8d374ba.woff2") format("woff2"),url("/assets/open-sans/open-sans ...

# %%
divLink = soup.find(class_='table-title')
print divLink.prettify()
# Out:
# <div class="table-title">
#  <h2>
#   Assets 2013
#  </h2>
#  <a href="/personal-finances/assets.csv?cid=N00001024&amp;year=2013">
#   <svg aria-hidden="true" class="Results-download-icon" focusable="false" height="16" preserveaspectratio="xMidYMid meet" role="img" viewbox="0 0 2048 2048" width="16" xmlns="http://www.w3.org/2000/svg">
#    <path d="M1472 1472q0-26-19-45t-45-19-45 19-19 45 19 45 45 19 45-19 19-45zm256 0q0-26-19-45t-45-19-45 19-19 45 19 45 45 19 45-19 19-45zm128-224v320q0 40-28 68t-68 28h-1472q-40 0-68-28t-28-68v-320q0-40 28-68t68-28h465l135 136q58 56 136 56t136-56l136-136h464q40 0 68 28t28 68zm-325-569q17 41-14 70l-448 448q-18 19-45 19t-45-19l-448-448q-31-29-14-70 17-39 59-39h256v-448q0-26 19-45t45-19h256q26 0 45 19t19 45v448h256q42 0 59 39z">
#    </path>
#   </svg>
#   <span>
#    Download .csv file
#   </span>
#  </a>
# </div>

# %%
RefLink = divLink.find_all('a', href=True)

# %%
# del downloadLink
print RefLink[0]['href']
# Out:
# /personal-finances/assets.csv?cid=N00001024&year=2013
