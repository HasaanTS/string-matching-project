# %%
import requests
from bs4 import BeautifulSoup
import collections
import pandas as pd
import numpy as np
import os

# %%
def file_write(df, path_and_name, idx=False):
    #This is a simple function that writes a dataframe to a csv file
    return df.to_csv(path_and_name+'.csv', sep = ';', index = idx)#Making index False helps ignore index column when writing file

# %%
def download_file(url):
    local_filename = str(url.split('?')[1])+'.csv'
    # NOTE the stream=True parameter below
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192): 
                if chunk: # filter out keep-alive new chunks
                    f.write(chunk)
                    # f.flush()
    return local_filename

# %%
def groupDownload(path, URL):
    _website = 'https://www.opensecrets.org'
    page = requests.get(URL)
    soup = BeautifulSoup(page.content)
    _options = soup.find_all('option')
    for _option in _options:
        _link = str(_option['value'])
        _link = _link.split('?')
        _link = str(_link[0])+'.csv?'+str(_link[1])
        os.chdir(path)
        download_file(url=_website+_link)

# %%
baseStr = 'https://www.opensecrets.org/personal-finances/assets/*?cid='

_saveDataDir = '/home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/'


_namePath = '/home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/Name_List/'
_files = sorted(os.listdir(_namePath))

for _file in _files:
    if ( (_file == 'NameList_cong_105_1998.csv') or (_file == 'NameList_cong_106_2000.csv') or (_file == 'NameList_cong_107_2002.csv')
       or (_file == 'NameList_cong_108_2004.csv') or (_file == 'NameList_cong_109_2006.csv') or (_file == 'NameList_cong_110_2008.csv')
       or (_file == 'NameList_cong_111_2010.csv') or (_file == 'NameList_cong_112_2012.csv') ):
        continue
    else:
        nameDF = pd.read_csv(_namePath+'/'+_file, delimiter=';')
        print nameDF.head()
        repID = nameDF.id.values
        repName = nameDF.name.values
        repName = [rep.replace(', ', '-') for rep in repName]
        congFolder = 'cong'+str(nameDF.congID.values[0])
    
        for i in range(len(repID)):
            try:
                os.makedirs(_saveDataDir+congFolder+'/'+str(repName[i])) #str(_saveDataDirList[i])+
                _savePath = _saveDataDir+congFolder+'/'+str(repName[i])+'/'
                groupDownload(path= _savePath, URL=baseStr+str(repID[i]))
            
            except:
                print _saveDataDir+congFolder+'/'+str(repName[i])
                _savePath = _saveDataDir+congFolder+'/'+str(repName[i])+'/'
                groupDownload(path= _savePath, URL=baseStr+str(repID[i]))
            
        
# #         print baseStr+str(_id)
#         page = requests.get(baseStr+str(repID[i]))
#         soup = BeautifulSoup(page.content)
#         _options = soup.find_all('option')
#         for _option in _options:
#             _link = str(_option['value'])
#             _link = _link.split('?')
#             _link = str(_link[0])+'.csv?'+str(_link[1])
# #             print _link
#             print _website+_link
            
#         break #for a single congress
    
#     break
# Out:
#    congID                               details         id  \
# 0     113  North Carolina Democrat, District 12  N00035451
# 1     113        Alabama Republican, District 4  N00003028
# 2     113          Tennessee Republican, Senate  N00009888
# 3     113       Michigan Republican, District 3  N00031938
# 4     113         Nevada Republican, District 2  N00031177
#
#                  name  year
# 0         Adams, Alma  2014
# 1  Aderholt, Robert B  2014
# 2    Alexander, Lamar  2014
# 3       Amash, Justin  2014
# 4        Amodei, Mark  2014
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/DeGette-Diana
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Delaney-John K
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/DeLauro-Rosa L
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/DelBene-Suzan
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Denham-Jeff
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Dent-Charlie
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/DeSantis-Ron
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Desjarlais-Scott
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Deutch-Ted
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Diaz-Balart-Mario
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Dingell-John D
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Doggett-Lloyd
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Donnelly-Joe
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Doyle-Mike
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Duckworth-Tammy
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Duffy-Sean P
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Duncan-Jeff
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Duncan-John J Jr
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Durbin-Dick
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Edwards-Donna
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Ellison-Keith
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Ellmers-Renee
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Engel-Eliot L
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Enyart-William
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Enzi-Mike
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Eshoo-Anna
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Esty-Elizabeth
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Faleomavaega-Eni F H
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Farenthold-Blake
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Farr-Sam
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Fattah-Chaka
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Feinstein-Dianne
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Fincher-Steve
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Fischer-Deb
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Fitzpatrick-Michael G
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Flake-Jeff
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Fleischmann-Chuck
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Fleming-John
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Flores-Bill
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Forbes-Randy
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Fortenberry-Jeff
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Foster-Bill
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Foxx-Virginia
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Frankel-Lois J
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Franken-Al
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Franks-Trent
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Frelinghuysen-Rodney
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Fudge-Marcia L
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Gabbard-Tulsi
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Gallego-Pete
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Garamendi-John
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Garcia-Joe
# /home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/cong113/Gardner-Cory
#    congID                               details         id  \
# 0     114      Louisiana Republican, District 5  N00036633
# 1     114  North Carolina Democrat, District 12  N00035451
# 2     114        Alabama Republican, District 4  N00003028
# 3     114      California Democrat, District 31  N00033997
# 4     114          Tennessee Republican, Senate  N00009888
#
#                  name  year
# 0      Abraham, Ralph  2016
# 1         Adams, Alma  2016
# 2  Aderholt, Robert B  2016
# 3       Aguilar, Pete  2016
# 4    Alexander, Lamar  2016

# %%
baseStr = 'https://www.opensecrets.org/personal-finances/assets/*?cid='

_saveDataDir = '/home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/FinancesData/'


_namePath = '/home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/Name_List/'
_files = sorted(os.listdir(_namePath))

last_file = '/home/hassaan/Data/TUM/2nd Year/4th Semester/IDP/Project/data/raw/Name_List/Top_Net_Worth.csv'
nameDF = pd.read_csv(last_file, delimiter=';')
#     print nameDF.head()
repID = nameDF.id.values
repName = nameDF.name.values
repName = [rep.replace(', ', '-') for rep in repName]
congFolder = 'TopNetWorth'
# print 'Cong#',str(nameDF.congID.values[0]), '\tEntries:', len(nameDF), '\n\n'

for i in range(len(repID)):
    try:
        os.makedirs(_saveDataDir+congFolder+'/'+str(repName[i])) #str(_saveDataDirList[i])+
        _savePath = _saveDataDir+congFolder+'/'+str(repName[i])+'/'
        groupDownload(path= _savePath, URL=baseStr+str(repID[i]))
            
    except:
        print _saveDataDir+congFolder+'/'+str(repName[i])
        _savePath = _saveDataDir+congFolder+'/'+str(repName[i])+'/'
        groupDownload(path= _savePath, URL=baseStr+str(repID[i]))
